# %%
def can_partition(nums):
    total_sum = sum(nums)
    
    # If total_sum is odd, partitioning into two equal subsets is impossible
    if total_sum % 2 != 0:
        return False
    
    target = total_sum // 2
    dp = [False] * (target + 1)
    dp[0] = True  # Base case: A sum of 0 is always possible
    
    for num in nums:
        print('num:', num)
        for j in range(target, num - 1, -1):  # Traverse backwards
            # print('j-num:', (j-num))
            dp[j] = dp[j] or dp[j - num]

        # shows the results with the number that has been iterated
        for i in range(target + 1):
            print(f'dp[{i}]={dp[i]}')

    # for i in range(target + 1):
    #     print(f'dp[{i}]={dp[i]}')
    
    return dp[target]

# Example usage
nums = [2, 3, 4, 6, 7, 8]
print(can_partition(nums))  # Output: True
# Out:
# num: 2
# dp[0]=True
# dp[1]=False
# dp[2]=True
# dp[3]=False
# dp[4]=False
# dp[5]=False
# dp[6]=False
# dp[7]=False
# dp[8]=False
# dp[9]=False
# dp[10]=False
# dp[11]=False
# dp[12]=False
# dp[13]=False
# dp[14]=False
# dp[15]=False
# num: 3
# dp[0]=True
# dp[1]=False
# dp[2]=True
# dp[3]=True
# dp[4]=False
# dp[5]=True
# dp[6]=False
# dp[7]=False
# dp[8]=False
# dp[9]=False
# dp[10]=False
# dp[11]=False
# dp[12]=False
# dp[13]=False
# dp[14]=False
# dp[15]=False
# num: 4
# dp[0]=True
# dp[1]=False
# dp[2]=True
# dp[3]=True
# dp[4]=True
# dp[5]=True
# dp[6]=True
# dp[7]=True
# dp[8]=False
# dp[9]=True
# dp[10]=False
# dp[11]=False
# dp[12]=False
# dp[13]=False
# dp[14]=False
# dp[15]=False
# num: 6
# dp[0]=True
# dp[1]=False
# dp[2]=True
# dp[3]=True
# dp[4]=True
# dp[5]=True
# dp[6]=True
# dp[7]=True
# dp[8]=True
# dp[9]=True
# dp[10]=True
# dp[11]=True
# dp[12]=True
# dp[13]=True
# dp[14]=False
# dp[15]=True
# num: 7
# dp[0]=True
# dp[1]=False
# dp[2]=True
# dp[3]=True
# ...

# %%
# def find_partition(nums):
#     total_sum = sum(nums)
    
#     if total_sum % 2 != 0:
#         return False, []
    
#     target = total_sum // 2
#     n = len(nums)
    
#     # Memoization table: dp[index][remaining_sum]
#     dp = [[-1 for _ in range(target + 1)] for _ in range(n)]

#     def subset_sum(index, remaining_sum, current_subset):
#         # Base cases
#         if remaining_sum == 0:
#             return True, current_subset
#         if index >= n or remaining_sum < 0:
#             return False, []
        
#         # Check memoized result
#         if dp[index][remaining_sum] != -1:
#             return dp[index][remaining_sum], current_subset
        
#         # Recursive calls: include or exclude the current number
#         include, subset_with_num = subset_sum(index + 1, remaining_sum - nums[index], current_subset + [nums[index]])
#         exclude, subset_without_num = subset_sum(index + 1, remaining_sum, current_subset)
        
#         # Memoize and return result
#         dp[index][remaining_sum] = include or exclude
#         if include:
#             return True, subset_with_num
#         else:
#             return False, subset_without_num
    
#     success, subset = subset_sum(0, target, [])
#     if success:
#         other_subset = [num for num in nums if num not in subset]
#         return True, (subset, other_subset)
    
#     return False, []

# # Test case
# nums = [3, 4, 6, 7, 2, 8]
# result, subsets = find_partition(nums)
# print("Result:", result)
# print("Subsets:", subsets)
# Out:
# Result: False
# Subsets: []
